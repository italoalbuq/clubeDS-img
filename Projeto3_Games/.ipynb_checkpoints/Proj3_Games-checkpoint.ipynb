# %% [markdown]
# # 0.0 Importar as bibliotecas

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import math
from IPython.display import Image
import pylab

# %% [markdown]
# # 0.1 Funções

# %% [markdown]
# # 0.2 Importação dos Dados

# %%
df_raw = pd.read_csv("Video Games Dataset.csv")

# %%
df_raw.head()
# Out:
#    Rank                      Name Platform  Year         Genre Publisher  \
# 0     1                Wii Sports      Wii  2006        Sports  Nintendo
# 1     2         Super Mario Bros.      NES  1985      Platform  Nintendo
# 2     3            Mario Kart Wii      Wii  2008        Racing  Nintendo
# 3     4         Wii Sports Resort      Wii  2009        Sports  Nintendo
# 4     5  Pokemon Red/Pokemon Blue       GB  1996  Role-Playing  Nintendo
#
#    NorthAmerica_Sales  EurpeanUnion_Sales  Japan_Sales  Other_Sales  \
# 0               41.49               29.02         3.77         8.46
# 1               29.08                3.58         6.81         0.77
# 2                 NaN               12.88         3.79          NaN
# 3               15.75               11.01          NaN         2.96
# 4               11.27                8.89        10.22         1.00
#
#    Global_Sales
# 0         82.74
# 1         40.24
# 2         35.82
# 3         33.00
# 4         31.37

# %% [markdown]
# # 1.0 Descrição dos Dados

# %%
# Copia de segurança
df1 = df_raw.copy()

# %% [markdown]
# # 1.1 Dimensão dos Dados

# %%
# Visualização da tabela: 199 linhas por 11 colunas
df1
# Out:
#      Rank                      Name Platform  Year         Genre  \
# 0       1                Wii Sports      Wii  2006        Sports
# 1       2         Super Mario Bros.      NES  1985      Platform
# 2       3            Mario Kart Wii      Wii  2008        Racing
# 3       4         Wii Sports Resort      Wii  2009        Sports
# 4       5  Pokemon Red/Pokemon Blue       GB  1996  Role-Playing
# ..    ...                       ...      ...   ...           ...
# 194   220                   FIFA 15      PS3  2014        Sports
# 195   221         Crash Team Racing       PS  1999        Racing
# 196   222                   FIFA 17      PS4  2016        Sports
# 197   223       Batman: Arkham City     X360  2011        Action
# 198   224                  Driver 2       PS  2000        Action
#
#                                   Publisher  NorthAmerica_Sales  \
# 0                                  Nintendo               41.49
# 1                                  Nintendo               29.08
# 2                                  Nintendo                 NaN
# 3                                  Nintendo               15.75
# 4                                  Nintendo               11.27
# ..                                      ...                 ...
# 194                         Electronic Arts                0.57
# 195             Sony Computer Entertainment                2.57
# 196                         Electronic Arts                0.28
# 197  Warner Bros. Interactive Entertainment                2.99
# 198                                     NaN                2.36
#
#      EurpeanUnion_Sales  Japan_Sales  Other_Sales  Global_Sales
# 0                 29.02         3.77         8.46         82.74
# 1                  3.58         6.81         0.77         40.24
# 2                 12.88         3.79          NaN         35.82
# 3                 11.01          NaN         2.96         33.00
# 4                  8.89        10.22         1.00         31.37
# ..                  ...          ...          ...           ...
# 194                3.14         0.04         1.07          4.82
# 195                1.57         0.44         0.21          4.79
# 196                3.75         0.06         0.69          4.77
# 197                1.31         0.04         0.41          4.76
# 198                2.10         0.02         0.25           NaN
#
# [199 rows x 11 columns]

# %%
# Linhas
df1.shape[0]
# Out:
# 199

# %%
# Colunas
df1.shape[1]
# Out:
# 11

# %% [markdown]
# # 1.2 Tipos de Dados

# %%
df1.dtypes
# Out:
# Rank                    int64
# Name                   object
# Platform               object
# Year                    int64
# Genre                  object
# Publisher              object
# NorthAmerica_Sales    float64
# EurpeanUnion_Sales    float64
# Japan_Sales           float64
# Other_Sales           float64
# Global_Sales          float64
# dtype: object

# %% [markdown]
# # 1.3 Checando dados faltantes (NaN)

# %%
# Quantidade de dados faltantes
df1.isna().sum()
# Out:
# Rank                   0
# Name                   0
# Platform               0
# Year                   0
# Genre                  0
# Publisher              1
# NorthAmerica_Sales    14
# EurpeanUnion_Sales     9
# Japan_Sales           10
# Other_Sales            7
# Global_Sales          12
# dtype: int64

# %% [markdown]
# # 1.4 Tratamento de dados faltantes

# %%
# Preencher um dado faltante da coluna Publisher
df1['Publisher'] = df1['Publisher'].fillna("Infogrames")

# De forma alternativa
#value1 = {"Publisher": 'Infogrames'}
#df1['Publisher'] = df1.fillna(value=value1)

# %%
# Mediana de vendas do continente Norte Americano
df1["NorthAmerica_Sales"].median()
# Out:
# 3.28

# %%
# Preencher os dados faltantes de todas as colunas com o comando lambda
# Colocar a mediana de vendas de todos os continentes

# Para todos os valores x: 
# Os valores que são não-numéricos NaN (quando é retornado True), atribuir o valor da mediana
# Os valores que são númericos (quando é retornado False), atribuir/manter o mesmo valor numérico

df1['NorthAmerica_Sales'] = df1['NorthAmerica_Sales'].apply( lambda x: 3.28 if math.isnan( x ) else x )

df1['EurpeanUnion_Sales'] = df1['EurpeanUnion_Sales'].apply(lambda x: 2.26 if math.isnan(x) else x)

df1['Japan_Sales'] = df1['Japan_Sales'].apply( lambda x: 0.65 if math.isnan(x) else x)

df1['Other_Sales'] = df1['Other_Sales'].apply( lambda x: 0.63 if math.isnan(x) else x)

df1['Global_Sales'] = df1['Global_Sales'].apply( lambda x: 7.13 if math.isnan(x) else x)

# %%
# Verificando se ainda tem dados faltantes
df1.isna().sum()
# Out:
# Rank                  0
# Name                  0
# Platform              0
# Year                  0
# Genre                 0
# Publisher             0
# NorthAmerica_Sales    0
# EurpeanUnion_Sales    0
# Japan_Sales           0
# Other_Sales           0
# Global_Sales          0
# dtype: int64

# %%
df1
# Out:
#      Rank                      Name Platform  Year         Genre  \
# 0       1                Wii Sports      Wii  2006        Sports
# 1       2         Super Mario Bros.      NES  1985      Platform
# 2       3            Mario Kart Wii      Wii  2008        Racing
# 3       4         Wii Sports Resort      Wii  2009        Sports
# 4       5  Pokemon Red/Pokemon Blue       GB  1996  Role-Playing
# ..    ...                       ...      ...   ...           ...
# 194   220                   FIFA 15      PS3  2014        Sports
# 195   221         Crash Team Racing       PS  1999        Racing
# 196   222                   FIFA 17      PS4  2016        Sports
# 197   223       Batman: Arkham City     X360  2011        Action
# 198   224                  Driver 2       PS  2000        Action
#
#                                   Publisher  NorthAmerica_Sales  \
# 0                                  Nintendo               41.49
# 1                                  Nintendo               29.08
# 2                                  Nintendo                3.28
# 3                                  Nintendo               15.75
# 4                                  Nintendo               11.27
# ..                                      ...                 ...
# 194                         Electronic Arts                0.57
# 195             Sony Computer Entertainment                2.57
# 196                         Electronic Arts                0.28
# 197  Warner Bros. Interactive Entertainment                2.99
# 198                              Infogrames                2.36
#
#      EurpeanUnion_Sales  Japan_Sales  Other_Sales  Global_Sales
# 0                 29.02         3.77         8.46         82.74
# 1                  3.58         6.81         0.77         40.24
# 2                 12.88         3.79         0.63         35.82
# 3                 11.01         0.65         2.96         33.00
# 4                  8.89        10.22         1.00         31.37
# ..                  ...          ...          ...           ...
# 194                3.14         0.04         1.07          4.82
# 195                1.57         0.44         0.21          4.79
# 196                3.75         0.06         0.69          4.77
# 197                1.31         0.04         0.41          4.76
# 198                2.10         0.02         0.25          7.13
#
# [199 rows x 11 columns]

# %% [markdown]
# # 1.5 Estatística Descritiva

# %%
num_attributes = df1.select_dtypes( include=['int64', 'float64'] )
cat_attributes = df1.select_dtypes( exclude=['int64', 'float64', 'datetime64[ns]'] )

# %%
num_attributes
# Out:
#      Rank  Year  NorthAmerica_Sales  EurpeanUnion_Sales  Japan_Sales  \
# 0       1  2006               41.49               29.02         3.77
# 1       2  1985               29.08                3.58         6.81
# 2       3  2008                3.28               12.88         3.79
# 3       4  2009               15.75               11.01         0.65
# 4       5  1996               11.27                8.89        10.22
# ..    ...   ...                 ...                 ...          ...
# 194   220  2014                0.57                3.14         0.04
# 195   221  1999                2.57                1.57         0.44
# 196   222  2016                0.28                3.75         0.06
# 197   223  2011                2.99                1.31         0.04
# 198   224  2000                2.36                2.10         0.02
#
#      Other_Sales  Global_Sales
# 0           8.46         82.74
# 1           0.77         40.24
# 2           0.63         35.82
# 3           2.96         33.00
# 4           1.00         31.37
# ..           ...           ...
# 194         1.07          4.82
# 195         0.21          4.79
# 196         0.69          4.77
# 197         0.41          4.76
# 198         0.25          7.13
#
# [199 rows x 7 columns]

# %%
cat_attributes
# Out:
#                          Name Platform         Genre  \
# 0                  Wii Sports      Wii        Sports
# 1           Super Mario Bros.      NES      Platform
# 2              Mario Kart Wii      Wii        Racing
# 3           Wii Sports Resort      Wii        Sports
# 4    Pokemon Red/Pokemon Blue       GB  Role-Playing
# ..                        ...      ...           ...
# 194                   FIFA 15      PS3        Sports
# 195         Crash Team Racing       PS        Racing
# 196                   FIFA 17      PS4        Sports
# 197       Batman: Arkham City     X360        Action
# 198                  Driver 2       PS        Action
#
#                                   Publisher
# 0                                  Nintendo
# 1                                  Nintendo
# 2                                  Nintendo
# 3                                  Nintendo
# 4                                  Nintendo
# ..                                      ...
# 194                         Electronic Arts
# 195             Sony Computer Entertainment
# 196                         Electronic Arts
# 197  Warner Bros. Interactive Entertainment
# 198                              Infogrames
#
# [199 rows x 4 columns]

# %%
df1.describe()
# Out:
#              Rank         Year  NorthAmerica_Sales  EurpeanUnion_Sales  \
# count  199.000000   199.000000          199.000000          199.000000
# mean   110.075377  2005.201005            4.601206            3.010804
# std     64.928627     7.452869            4.641746            2.795433
# min      1.000000  1982.000000            0.000000            0.000000
# 25%     55.500000  1999.000000            2.635000            1.665000
# 50%    107.000000  2007.000000            3.280000            2.260000
# 75%    163.500000  2011.000000            4.990000            3.410000
# max    224.000000  2016.000000           41.490000           29.020000
#
#        Japan_Sales  Other_Sales  Global_Sales
# count   199.000000   199.000000    199.000000
# mean      1.307387     0.807035      9.696935
# std       1.686511     0.837650      8.071899
# min       0.000000     0.000000      4.760000
# 25%       0.090000     0.320000      5.515000
# 50%       0.650000     0.630000      7.130000
# 75%       1.975000     1.000000     10.455000
# max      10.220000     8.460000     82.740000

# %% [markdown]
# # 2.0 Feature Engineering

# %%
Image("Imagens/Jogos.png")

# %% [markdown]
# # 2.1 Hipóteses

# %% [markdown]
# Quais são os três jogos mais vendidos em outros países?
#
# Quais são os três jogos menos vendidos em outros países?
#
# Quais serão os jogos mais vendidos em 2017?
#
# Qual jogo teve maior quantidade de vendas no globo?
#
# Qual plataforma teve maior quantidade de vendas?
#
# Qual gênero teve a maior quantia de vendas?
#
# Qual a região do mundo teve a maior quantidade de vendas?

# %% [markdown]
# # 3.0 Análise Exploratória

# %% [markdown]
# ## 3.1 Análise Univariada

# %%
pylab.rcParams['figure.figsize'] = (20, 12)
num_attributes.hist(bins=25);

# %% [markdown]
# # 3.2 Análise Bivariada

# %% [markdown]
# Quais são os três jogos mais vendidos em outros países?
